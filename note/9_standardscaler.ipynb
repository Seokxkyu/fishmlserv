# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fish_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]

fish_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# %%
fish_data = np.column_stack((fish_length, fish_weight))

# %%
o = np.ones(35)
z = np.zeros(14)
fish_target = np.concatenate((o, z))

# %%
fish_target = np.concatenate((np.ones(35), np.zeros(14)))

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier(n_neighbors=5)
kn.fit(fish_data, fish_target)
# Out:
# KNeighborsClassifier()

# %%
kn.predict([[25, 150]])
# Out:
# array([0.])

# %%
plt.scatter(fish_data[:,0], fish_data[:,1])
plt.scatter(25, 150, c='red', marker="*")
plt.scatter(fish_data[indexes, 0], fish_data[indexes, 1], c='green', marker="D")
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
distances, indexes = kn.kneighbors([[25, 150]])

# %%
indexes
# Out:
# array([[ 0, 48, 47, 45, 46]])

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
fish_data_scaled = ss.fit_transform(fish_data)

# %%
kn2 = KNeighborsClassifier(n_neighbors=5)
kn2.fit(fish_data_scaled, fish_target)
# Out:
# KNeighborsClassifier()

# %%
kn2.predict([[25, 150]])
# Out:
# array([1.])

# %%
test_scaled = ss.fit_transform([[25, 150]])

# %%
test_scaled[0]
# Out:
# np.float64(0.0)

# %%
kn2.predict(test_scaled)
# Out:
# array([1.])

# %%
plt.scatter(fish_data_scaled[:,0], fish_data_scaled[:,1])
plt.scatter(test_scaled[0,0], test_scaled[0,1], c='red', marker="*")
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
mean = np.mean(fish_data, axis=0)
std = np.std(fish_data, axis=0)

# %%
train_scaled = (fish_data - mean) / std
kn.fit(train_scaled, fish_target)
# Out:
# KNeighborsClassifier()

# %%
domi = [25, 150]
domi_scaled = (domi - mean) / std
kn.predict([domi_scaled])
# Out:
# array([1.])

# %%
distances, indexes = kn.kneighbors([domi_scaled])

# %%
indexes
# Out:
# array([[0, 1, 2, 3, 7]])

# %%
plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(domi_scaled[0], domi_scaled[1], c='red', marker="*")
plt.scatter(train_scaled[indexes, 0], train_scaled[indexes, 1], c='green', marker="D")
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
# n_neighbors 5, 15, 25, 49로 변경해서 훈련, 예측, 산점도 그려보기

from sklearn.neighbors import KNeighborsClassifier
kn15 = KNeighborsClassifier(n_neighbors=15)
kn15.fit(train_scaled, fish_target)

kn15.predict([domi_scaled])

distances, indexes = kn15.kneighbors([domi_scaled])

plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(domi_scaled[0], domi_scaled[1], c='red', marker="*")
plt.scatter(train_scaled[indexes, 0], train_scaled[indexes, 1], c='green', marker="D")
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
# n_neighbors 5, 15, 25, 49로 변경해서 훈련, 예측, 산점도 그려보기

from sklearn.neighbors import KNeighborsClassifier
kn25 = KNeighborsClassifier(n_neighbors=25)
kn25.fit(train_scaled, fish_target)

kn25.predict([domi_scaled])

distances, indexes = kn25.kneighbors([domi_scaled])

plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(domi_scaled[0], domi_scaled[1], c='red', marker="*")
plt.scatter(train_scaled[indexes, 0], train_scaled[indexes, 1], c='green', marker="D")
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
# n_neighbors 5, 15, 25, 49로 변경해서 훈련, 예측, 산점도 그려보기

from sklearn.neighbors import KNeighborsClassifier
kn1 = KNeighborsClassifier(n_neighbors=1)
kn1.fit(train_scaled, fish_target)

kn1.predict([domi_scaled])

distances, indexes = kn1.kneighbors([domi_scaled])

plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(domi_scaled[0], domi_scaled[1], c='red', marker="*")
plt.scatter(train_scaled[indexes, 0], train_scaled[indexes, 1], c='green', marker="D")
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
# n_neighbors 5, 15, 25, 49로 변경해서 훈련, 예측, 산점도 그려보기

from sklearn.neighbors import KNeighborsClassifier
kn49 = KNeighborsClassifier(n_neighbors=49)
kn49.fit(train_scaled, fish_target)

kn49.predict([domi_scaled])

distances, indexes = kn49.kneighbors([domi_scaled])

plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(domi_scaled[0], domi_scaled[1], c='red', marker="*")
plt.scatter(train_scaled[indexes, 0], train_scaled[indexes, 1], c='green', marker="D")
plt.xlabel('length')
plt.ylabel('weight')
plt.show()
